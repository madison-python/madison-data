# %% [markdown]
# # This is a Jupyter Notebook

# %% [markdown]
# ## Pandas
#
# Pandas is awesome.
#
# ### Installation
#
# Pandas should come standard with an Anaconda installation that gives the whole scipy stack.  Otherwise, installing Pandas is as simple as running `pip install pandas`.  You will also need to run `pip install xlrd` if you want to read excel files.  You can then use the pandas package in your code by importing it:
#
# ```python
# import pandas
# ```
# or, often imported as shorter alias:
# ```python
# import pandas as pd
# ```
#
# **Try it!**

# %%
import pandas as pd

# %% [markdown]
# In a jupyter notebook, if you want more information about a function or module you import from another library, just ask!

# %%
pd?

# %% [markdown]
# Pandas is for dealing with tabular/spreadsheet data.
#
# There are various read functions to load data, like `pd.read_csv()` and `pd.read_excel()`.  Check out the [API Reference](https://pandas.pydata.org/pandas-docs/stable/api.html) for all the details on how to load data into Pandas.
#
# Our data is in CSV form so we will use that function.  It actually reads directly from the URL:

# %%
police_reports = pd.read_csv("https://opendata.arcgis.com/datasets/61c36ee8e2d14cd094a265a288e27151_2.csv")

# %% [markdown]
# If for some reason that doesn't work, you can just read the file directly from your filesystem.

# %%
police_reports = pd.read_csv("Police_Incident_Reports.csv")

# %% [markdown]
# `police_reports` is a "Dataframe" object:

# %%
type(police_reports)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# It looks like this:

# %%
police_reports
# Out:
#        IncidentID                                     IncidentType  \
# 0            7400  Assist Outside Agency
# 1            7401  Arrested Person
# 2            7402  Arrested Person
# 3            7403  Arrested Person
# 4            7404  Information
# 5            7405  Disturbance
# 6            7406  Accident - Hit & Run
# 7            7407  Assist Outside Agency
# 8            7408  Murder/Homicide
# 9            7409  Murder/Homicide
# 10           7410  Found Person
# 11           7411  Aggravated Assault
# 12           7412  Strong Armed Robbery
# 13           7413  Residential Burglary
# 14           7414  Accident - Injury
# 15           7415  Accident - Injury
# 16           7416  Person Down
# 17           7417  Arrested Person
# 18           7418  Weapons Violation
# 19           7419  Drug Investigation
# 20           7420  Accident - Injury
# 21           7421  Weapons Violation
# 22           7422  Retail Theft
# 23           7423  Suspicious Person
# 24           7424  Information
# 25           7425  Arrested Person
# 26           7426  Strong Armed Robbery
# 27           7427  Battery
# 28           7428  Weapons Violation
# 29           7429  Assist Citizen
# ...           ...                                              ...
# 11490       20971                                          Robbery
# 11491       20972                                Weapons Violation
# 11492       20973                                Weapons Violation
# 11493       20974                                Weapons Violation
# 11494       20975                                Weapons Violation
# 11495       20976                                          Robbery
# 11496       20977                                 Damaged Property
# 11497       20978                                Weapons Violation
# 11498       20979                                          Robbery
# 11499       20980                                          Battery
# 11500       20981                                          Robbery
# 11501       20982                                Weapons Violation
# 11502       20983                                Weapons Violation
# 11503       20984                                          Robbery
# 11504       20985                                          Robbery
# 11505       20986                                          Battery
# 11506       20987                                      Disturbance
# 11507       20988                                            Theft
# 11508       20989                                  Arrested Person
# 11509       20990                                          Robbery
# 11510       20991                                Weapons Violation
# 11511       20992                                Weapons Violation
# 11512       20993                         Non-Residential Burglary
# 11513       20994                               Drug Investigation
# 11514       20995                                            Theft
# 11515       20996                                          Battery
# 11516       20997                               Drug Investigation
# 11517       20998                                Weapons Violation
# 11518       21998                                            Theft
# 11519       21999                                          Robbery
#
#                                               CaseNumber  \
# 0      2005-13680                                    ...
# 1      2005-22647                                    ...
# 2      2005-22345                                    ...
# 3      2005-22688                                    ...
# 4      2005-999999                                   ...
# 5      2005-23610                                    ...
# 6      2005-23461                                    ...
# 7      2005-23957                                    ...
# 8      05-24600                                      ...
# 9      2005-24600                                    ...
# 10     2005-24346                                    ...
# 11     2005-24405                                    ...
# 12     2005-24777                                    ...
# 13     2005-25006                                    ...
# 14     2005-25436                                    ...
# 15     05- 26248                                     ...
# 16     2005-26771                                    ...
# 17     2005-26241                                    ...
# 18     2005-26141                                    ...
# 19     2005-26680                                    ...
# 20     2005-27610                                    ...
# 21     2005-25096                                    ...
# 22     2005-27764                                    ...
# 23     2005-28217                                    ...
# 24     2005-28544                                    ...
# 25     2005-28436                                    ...
# 26     2005-29601                                    ...
# 27     2005-28235                                    ...
# 28     2005-30366                                    ...
# 29     2005-30392                                    ...
# ...                                                  ...
# 11490                                        2018-298686
# 11491                                        2018-298759
# 11492                                        2018-299562
# 11493                                        2018-300713
# 11494                                        2018-301440
# 11495                                        2018-301380
# 11496                                        2018-303098
# 11497                                        2018-303306
# 11498                                        2018-301671
# 11499                                        2018-304300
# 11500                                        2018-305254
# 11501                                        2018-305889
# 11502                                        2018-305268
# 11503                                        2018-306594
# 11504                                        2018-307817
# 11505                                        2018-307491
# 11506                                        2018-308233
# 11507                                        2018-308929
# 11508                                        2018-309942
# 11509                                        2018-311630
# 11510                                        2018-311527
# 11511                                        2018-312373
# 11512                                        2018-313090
# 11513                                        2018-147714
# 11514                                        2018-310622
# 11515                                        2018-312247
# 11516                                        2018-270843
# 11517                                        2018-314343
# 11518                                        2018-311685
# 11519                                        2018-314334
#
#                    IncidentDate  \
# 0      2005-10-06T22:33:00.000Z
# 1      2005-03-02T23:42:00.000Z
# 2      2005-03-02T08:30:00.000Z
# 3      2005-03-03T07:30:00.000Z
# 4      2005-03-04T13:45:00.000Z
# 5      2005-03-05T03:25:00.000Z
# 6      2005-03-05T20:45:00.000Z
# 7      2005-03-06T01:08:00.000Z
# 8      2005-03-07T20:05:00.000Z
# 9      2005-03-07T20:06:00.000Z
# 10     2005-03-07T09:22:00.000Z
# 11     2005-03-07T11:57:00.000Z
# 12     2005-03-08T12:07:00.000Z
# 13     2005-03-09T01:55:00.000Z
# 14     2005-03-10T09:07:00.000Z
# 15     2005-03-12T02:44:00.000Z
# 16     2005-03-13T15:14:00.000Z
# 17     2005-03-12T02:30:00.000Z
# 18     2005-03-11T21:13:00.000Z
# 19     2005-03-13T00:00:00.000Z
# 20     2005-03-15T22:31:00.000Z
# 21     2005-03-09T11:15:00.000Z
# 22     2005-03-16T11:48:00.000Z
# 23     2005-03-17T07:30:00.000Z
# 24     2005-03-18T07:46:00.000Z
# 25     2005-03-17T23:14:00.000Z
# 26     2005-03-21T01:19:00.000Z
# 27     2005-03-17T15:40:00.000Z
# 28     2005-03-23T11:18:00.000Z
# 29     2005-03-23T12:49:00.000Z
# ...                         ...
# 11490  2018-08-05T01:49:00.000Z
# 11491  2018-08-05T03:12:00.000Z
# 11492  2018-08-05T19:15:00.000Z
# 11493  2018-08-06T15:51:00.000Z
# 11494  2018-08-07T04:25:00.000Z
# 11495  2018-08-07T00:15:00.000Z
# 11496  2018-08-08T09:32:00.000Z
# 11497  2018-08-08T11:53:00.000Z
# 11498  2018-08-07T09:00:00.000Z
# 11499  2018-08-09T00:27:00.000Z
# 11500  2018-08-09T15:54:00.000Z
# 11501  2018-08-10T01:27:00.000Z
# 11502  2018-08-09T15:45:00.000Z
# 11503  2018-08-10T14:06:00.000Z
# 11504  2018-08-11T10:40:00.000Z
# 11505  2018-08-11T01:26:00.000Z
# 11506  2018-08-11T16:25:00.000Z
# 11507  2018-08-12T02:30:00.000Z
# 11508  2018-08-12T21:07:00.000Z
# 11509  2018-08-14T02:16:00.000Z
# 11510  2018-08-14T23:03:00.000Z
# 11511  2018-08-14T15:40:00.000Z
# 11512  2018-08-15T01:05:00.000Z
# 11513  2018-08-07T10:30:00.000Z
# 11514  2018-08-14T14:00:00.000Z
# 11515  2018-08-14T14:22:00.000Z
# 11516  2018-08-07T12:30:00.000Z
# 11517  2018-08-15T18:29:00.000Z
# 11518  2018-08-14T04:59:00.000Z
# 11519  2018-08-15T18:28:00.000Z
#
#                                                  Suspect  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 11490                                                NaN
# 11491                           Continuing Investigation
# 11492  M, B, 14 yoa, wearing a bright orange shirt an...
# 11493                                                NaN
# 11494                                                NaN
# 11495                                                NaN
# 11496                                                NaN
# 11497                                                NaN
# 11498  M, W, 20-28 yoa, dark hair, 5"8"-6', wearing a...
# 11499                                                NaN
# 11500     M/W 5'04"-5'05", 130#'s Grey hooded sweatshirt
# 11501                                                NaN
# 11502                                                NaN
# 11503  Male, white, 5'6" to 5'8", 140 pounds, wearing...
# 11504  Male, white, 5'3" to 5'4", slender build, mid ...
# 11505                                                NaN
# 11506                                                NaN
# 11507                                                NaN
# 11508                                                NaN
# 11509  Male, African American, approximately 22 years...
# 11510                                                NaN
# 11511                                                NaN
# 11512  Male, black, around 30, 5'7" to 5'8", muscular...
# 11513                                                NaN
# 11514                                                NaN
# 11515                                                NaN
# 11516                                                NaN
# 11517                                                NaN
# 11518                                                NaN
# 11519                                                NaN
#
#                                                 Arrested  \
# 0                                                    ...
# 1      Tony R Markovitch, 20 years old, 301 Knutson D...
# 2      Martell D. Britton m/b 05-03-85\r\r\nCharge:  ...
# 3      Twainesse L Peavy, 26 yrs old, 2317 Fish Hatch...
# 4                                                    ...
# 5                                                    ...
# 6      Carlos A Rivas\r\r\n32 years old\r\r\n-Battery...
# 7      Jacob J Verriden\r\r\n25 years old\r\r\n-Inter...
# 8      MALE                                          ...
# 9      DeWayne K Allen, 02-26-1957, resident of Madis...
# 10     N/A                                           ...
# 11     Black male teenager, 5'9", wearing long black ...
# 12     Suspect:  Christopher L Freeman, age 32, 8317 ...
# 13     Suspect #1:\r\r\nM/B 20-25 years old, 5'11 180...
# 14     n/a                                           ...
# 15     Driver of vehicle in custody, identity withhel...
# 16     None                                          ...
# 17     Daniel Littlejohn\r\r\n22 years old\r\r\nMadis...
# 18     Suspect:\r\r\nAsian Male\r\r\napproximately 5...
# 19     Torey Michael Henry Huegli\r\r\n30 years old\r...
# 20                                                   ...
# 21     16 yr old male: weapons violations\r\r\n\r\r\n...
# 22     Robert Gundy\r\r\n57 years old\r\r\nMadison\r\...
# 23     M/B approx. 30 Short hair, Dark Green New 4 dr...
# 24     n/a                                           ...
# 25     Jorge Gonzales-Guttierrez\r\r\n18 yrs old\r\r\...
# 26     Suspect- M/B, 30 YOA, stocky build. Wearing li...
# 27     16 year-old female:  Disorderly Conduct, Batte...
# 28                                                   ...
# 29                                                   ...
# ...                                                  ...
# 11490  Emmanuel L. Harris, age 21, Madison\r\nSuspect...
# 11491                           Continuing Investigation
# 11492                                                NaN
# 11493                                                NaN
# 11494                                                NaN
# 11495                                                NaN
# 11496                                                NaN
# 11497                                                NaN
# 11498                                                NaN
# 11499  Toby L. Jones, age 48, Madison\r\nJones was ar...
# 11500                                                NaN
# 11501  Tony D. Smith, age 30, Madison\r\nSuspect was ...
# 11502                                                NaN
# 11503                                                NaN
# 11504                                                NaN
# 11505  Kerry R. Steele, age 33, Madison\r\nSuspect wa...
# 11506  Female, age 16, Madison\r\nSuspect was arreste...
# 11507                                                NaN
# 11508  Michael J. Cisneros, age 42, Madison\r\nSuspec...
# 11509                                                NaN
# 11510                                                NaN
# 11511                                                NaN
# 11512                                                NaN
# 11513  Huey D. Smith, Jr., age 49, Madison\r\nSuspect...
# 11514  Male, age 13, Madison\r\nSuspect was arrested ...
# 11515  Edward I. Smith, age 35, Madison\r\nSmith was ...
# 11516  Lorrell A. McCray, Jr., age 29, Madison\r\nSus...
# 11517                                                NaN
# 11518  Male, age 14, Madison\r\nTeen was arrested for...
# 11519  Valerie L. Czebotar, age 38, Madison\r\nSuspec...
#
#                                                  Address  \
# 0      700 Block of E. Washington Ave.               ...
# 1      First St & E Washington Ave                   ...
# 2      8 New Berm Court                              ...
# 3      4300 Lumley Rd                                ...
# 4      211 S. Carroll Street                         ...
# 5      5800 block of Balsam Rd                       ...
# 6      4700 block of E. Washington Ave               ...
# 7      600 block of Langdon St                       ...
# 8      4700 COTTAGE GROVE RD                         ...
# 9      4700 Cottage Grove Rd. (block)                ...
# 10     Moland St                                     ...
# 11     1221 Huxley Street                            ...
# 12     2800 block of Cimarron Trl                    ...
# 13     400 block of W. Doty                          ...
# 14     2300 block of Allied Dr                       ...
# 15     Park St. at Regent St.                        ...
# 16     4 Collins Court (HY 51/Broadway)              ...
# 17     1900 block of N. Sherman Ave                  ...
# 18     6700 block of Schroeder Rd                    ...
# 19     7400 block of Mineral Point Rd                ...
# 20     1000 County Hwy. M                            ...
# 21     7700 block of Radcliffe Dr                    ...
# 22     4500 block of Verona Rd                       ...
# 23     Milwaukee St./ Rosemary St.                   ...
# 24     E Washington Ave at Lexington                 ...
# 25     5600 block of Odana Rd                        ...
# 26     1401 Regent St.- Open Pantry                  ...
# 27     2222 E. Washington Ave                        ...
# 28     202 State St                                  ...
# 29     3300 Atwood Ave                               ...
# ...                                                  ...
# 11490                      800 block of N Thompson Drive
# 11491                              118 S. Bedford Street
# 11492                                2920 N. Sherman Ave
# 11493                      2100 block Sunnyside Crescent
# 11494                                      Windigo Trail
# 11495                                    Radcliffe Drive
# 11496                                     1 Speedway Rd.
# 11497                               3600 block Cross St.
# 11498                        W. Doty St. at S. Broom St.
# 11499                                      317 State St.
# 11500                                 1574 W Broadway Dr
# 11501                                  415 N Lake Street
# 11502                              900 block S. Park St.
# 11503                          3762 East Washington Ave.
# 11504                              4225 East Towne Blvd.
# 11505                                 406 N. Frances St.
# 11506                       1100 block Morraine View Dr.
# 11507                           200 block S. Bassett St.
# 11508                                       Bluejay Lane
# 11509                             4726 E. Washington Ave
# 11510                                      Schroeder Rd.
# 11511                                      1800 Axel Ave
# 11512                                   1980 Atwood Ave.
# 11513                             1100 block Jenifer St.
# 11514                             50 block S. Gammon Rd.
# 11515                      2100 block of University Ave.
# 11516                            3600 block Brigham Ave.
# 11517                                5400 Commercial Ave
# 11518                                    Marinette Trail
# 11519                                  622 E. Gorham St.
#
#                                                   Victim  \
# 0                                                    ...
# 1      n/a                                           ...
# 2      Home Depot                                    ...
# 3      Adult male resident of Madison                ...
# 4                                                    ...
# 5                                                    ...
# 6                                                    ...
# 7      n/a                                           ...
# 8      MALE CHEST WOUNDS                             ...
# 9      Deceased. Identity withheld pending notificati...
# 10     N/a                                           ...
# 11     15-year old male, high school student, receive...
# 12     Adult male resident of Madison, WI\r\r\n\r\r\n...
# 13                                                   ...
# 14     67 year old male, resident of Dane County conv...
# 15     Three individuals transported to area hospital...
# 16     49 yr old male Rhinelander resident           ...
# 17                                                   ...
# 18     Victim:\r\r\nM/B 18 years old\r\r\n           ...
# 19                                                   ...
# 20     Samuel O. Clay, 18 year old from Middleton.  D...
# 21     n/a                                           ...
# 22                                                   ...
# 23                                                   ...
# 24     n/a                                           ...
# 25                                                   ...
# 26     No injuries.                                  ...
# 27                                                   ...
# 28                                                   ...
# 29     Man & dog                                     ...
# ...                                                  ...
# 11490                              Male, age 51, Madison
# 11491                                   33-year-old male
# 11492                            M, H, 45 yoa, Fitchburg
# 11493                        Male, age 19, McFarland, WI
# 11494                                                NaN
# 11495                            Female, age 27, Madison
# 11496                                                NaN
# 11497                                                NaN
# 11498                               F, W, 26 yoa, Oregon
# 11499  Female, age 36, Madison\r\nMale, age 27, Madis...
# 11500                                                NaN
# 11501                                                NaN
# 11502                                     Female, age 38
# 11503                                                NaN
# 11504                                                NaN
# 11505                          Male, age 33, Baraboo, WI
# 11506                                                NaN
# 11507                              Male, age 21, Madison
# 11508                                                NaN
# 11509                               Female, 18 years old
# 11510                                                NaN
# 11511                                                NaN
# 11512                                                NaN
# 11513                                                NaN
# 11514                                                NaN
# 11515                                                NaN
# 11516                                                NaN
# 11517                                                NaN
# 11518                              Male, age 68, Madison
# 11519                      Male, age 54, address unknown
#
#                                                  Details  \
# 0      On 2/6/05 at approximately 10:33 p.m. Officer ...
# 1      At approximately 11:42 pm, an officer noted a ...
# 2      On 03/02/2005 at approximately 8:15 am, the Ma...
# 3      At approximately 7:30 am this date, Officers r...
# 4      DELIVERY NOTICES FOR UNPAID PARKING TICKETS\r\...
# 5      On 3/5/05 at approximately 3:25 am, Madison Po...
# 6      On 3/4/05 at approximately 8:45 pm Madison Pol...
# 7      On 3/6/05 at approximately 1:08 am, Madison Po...
# 8      \r\r\nPolice responded to the 4700 block of Co...
# 9      On 3-7-2005, at 8:06pm, Madison Police respond...
# 10     On 3/7/05 at approximately 9:22 am MPD officer...
# 11     At approximately 11:57 am, on 3-7-05, Officers...
# 12     At approximately 12:07 pm on Tuesday, 03/08/05...
# 13     On 3/9/05 at approximately 1:55 am Madison Pol...
# 14     At approximately 9:07 am, Madison Police respo...
# 15     Involved vehicle northbound on Park St. Three ...
# 16     Officers were dispatched to the Arby's lot jus...
# 17     On 3/12/05 at approximately 2:30 am Madison Po...
# 18     On 3/11/05 at approximately 9:13 pm Madison Po...
# 19     On 3/13/05 Madison Police Officers were dispat...
# 20     At 10:31pm, Madison Police responded to the sc...
# 21     On 3/9/05 at approximately 11:15 am Madison Po...
# 22     On 3/16/2005 at approximately 11:48 am Madison...
# 23     The suspect approached a 16 year old female at...
# 24     At approximately 7:46 am, Capitol Police repor...
# 25     On 3/17/05 at approximately 11:14 pm a Madison...
# 26     Suspect entered store, approached clerk. Suspe...
# 27     On 3/17/05 at approximately 3:40 pm Madison Po...
# 28     On 3/23/05 at approximately 11:18 a.m. nine Ma...
# 29     On 3/23/2005 at approximately 12:49 pm Madison...
# ...                                                  ...
# 11490  The Madison Police were dispatched to the repo...
# 11491  Officers were dispatched to the WORT radio sta...
# 11492  A worker was inside of the stadium when he obs...
# 11493  A McFarland teen was shot in the hand and suff...
# 11494  &nbsp;Concerned residents, living near Windigo...
# 11495  &nbsp;A Radcliffe Drive resident said three me...
# 11496  Numerous headstones at Madison's <a href="http...
# 11497  &nbsp;The MPD is on the scene of a daytime sho...
# 11498  A woman parked her car near the intersection o...
# 11499  &nbsp;Bar patrons and employees helped hold a ...
# 11500  &nbsp;Officers were dispatched to a robbery of...
# 11501  Madison Police officers were near the intersec...
# 11502  &nbsp;A bicyclist was shot twice in the buttoc...
# 11503  &nbsp;No weapon was scene, but a robber demand...
# 11504  &nbsp;A robber passed a note indicating he had...
# 11505  &nbsp;A 33-year-old Madison man was arrested f...
# 11506  &nbsp;A 16-year-old girl attempted to disarm a...
# 11507  &nbsp;Letting a bunch of people you do not kno...
# 11508  &nbsp;He had a lighter in his hand, and was se...
# 11509  The Madison Police were called this morning to...
# 11510  &nbsp;A mother was walking with her 9-year-old...
# 11511  MPD officers responded to the area of 1800 Axe...
# 11512  A burglar entered an Atwood Ave. restaurant th...
# 11513  &nbsp;Complaints from residents in the Jenifer...
# 11514  With help from the MPD's Gang Unit, two teens ...
# 11515  &nbsp;A contractor, hired to install new carpe...
# 11516  &nbsp;The Dane County Narcotics Task Force, wi...
# 11517  A resident in the 5400 block of Commercial Ave...
# 11518  &nbsp;The four teens had just been taken into ...
# 11519  &nbsp;It is part of his routine, every day he ...
#
#                                      ReleasedBy              DateModified
# 0      Mike Hanson                                                    NaN
# 1      Lt Pat Malloy                                                  NaN
# 2      Lt. T. Peterson                                                NaN
# 3      Lt. Pat Malloy                                                 NaN
# 4      Lieutenant Joe Balles                                          NaN
# 5      Mike Hanson                                                    NaN
# 6      Mike Hanson                                                    NaN
# 7      Mike Hanson                                                    NaN
# 8      Lt. Carl Strasburg                                             NaN
# 9      Mike hanson                                                    NaN
# 10     Mike Hanson                                                    NaN
# 11     Lt. Pat Malloy                                                 NaN
# 12     Lt Pat Malloy                                                  NaN
# 13     Mike Hanson                                                    NaN
# 14     Lt Pat Malloy                                                  NaN
# 15     Lt. A. Bitterman                                               NaN
# 16     Sgt. Sue Armagost                                              NaN
# 17     Mike Hanson                                                    NaN
# 18     Mike Hanson                                                    NaN
# 19     Mike Hanson                                                    NaN
# 20     Lt. A. Bitterman/Kamholz                                       NaN
# 21     Mike Hanson                                                    NaN
# 22     Mike Hanson                                                    NaN
# 23     Sgt. Rachael Peterson                                          NaN
# 24     Lt Pat Malloy                                                  NaN
# 25     Mike Hanson                                                    NaN
# 26     Lt. A. Bitterman                                               NaN
# 27     Mike Hanson                                                    NaN
# 28     Mike Hanson                                                    NaN
# 29     Mike Hanson                                                    NaN
# ...                                         ...                       ...
# 11490                           Lt. Daniel Nale  2018-08-10T09:41:40.000Z
# 11491                         P.O. Howard Payne  2018-08-06T10:31:37.000Z
# 11492                            Lt. Jamar Gary                       NaN
# 11493                          PIO Joel Despain                       NaN
# 11494                          PIO Joel Despain                       NaN
# 11495                          PIO Joel Despain                       NaN
# 11496                          PIO Joel Despain                       NaN
# 11497                          PIO Joel Despain  2018-08-08T12:56:54.000Z
# 11498                            Lt. Jamar Gary                       NaN
# 11499                          PIO Joel Despain                       NaN
# 11500                        Sgt. Jennifer Kane  2018-08-10T09:27:53.000Z
# 11501                           Lt. Daniel Nale  2018-08-10T09:57:17.000Z
# 11502                          PIO Joel Despain                       NaN
# 11503                          PIO Joel Despain                       NaN
# 11504                          PIO Joel Despain                       NaN
# 11505                          PIO Joel Despain                       NaN
# 11506                          PIO Joel Despain                       NaN
# 11507                          PIO Joel Despain                       NaN
# 11508                          PIO Joel Despain                       NaN
# 11509                           Lt. Daniel Nale                       NaN
# 11510                          PIO Joel Despain                       NaN
# 11511                            Lt. Jamar Gary                       NaN
# 11512                          PIO Joel Despain                       NaN
# 11513                          PIO Joel Despain                       NaN
# 11514                          PIO Joel Despain                       NaN
# 11515                          PIO Joel Despain                       NaN
# 11516                          PIO Joel Despain                       NaN
# 11517                            Lt. Jamar Gary                       NaN
# 11518                          PIO Joel Despain  2018-08-16T11:17:34.000Z
# 11519                          PIO Joel Despain                       NaN
#
# [11520 rows x 11 columns]

# %%
len(police_reports)
# Out:
# 11520

# %%
type(police_reports["IncidentType"])
# Out:
# pandas.core.series.Series

# %%
sorted(police_reports["IncidentType"].unique())
# Out:
# [' Escapee/Absconder                             ',
#  '911 Disconnect',
#  'Accident - Bicycle',
#  'Accident - Hit & Run',
#  'Accident - Hit & Run                           ',
#  'Accident - Injury',
#  'Accident - Injury                              ',
#  'Accident - Injury                                 ',
#  'Accident - No Injury',
#  'Accident - No Injury                           ',
#  'Accident - Private Property',
#  'Accident - Private Property                    ',
#  'Accident - Private Property                       ',
#  'Aggravated Assault',
#  'Aggravated Assault                             ',
#  'Animal Complaint - Bite',
#  'Animal Complaint - Bite                        ',
#  'Animal Complaint - Disturbance',
#  'Animal Complaint - Disturbance                 ',
#  'Animal Complaint - Stray',
#  'Animal Complaint - Stray                       ',
#  'Annoying Phone Call',
#  'Arrested Juvenile',
#  'Arrested Juvenile                              ',
#  'Arrested Person',
#  'Arrested Person                                ',
#  'Arson Investigation',
#  'Arson Investigation                            ',
#  'Assist Citizen',
#  'Assist Citizen                                 ',
#  'Assist Outside Agency',
#  'Assist Outside Agency                          ',
#  'Attempt to Locate Person',
#  'Attempted Homicide',
#  'Attempted Homicide                             ',
#  'Attempted Suicide',
#  'Attempted Suicide                              ',
#  'Battery',
#  'Battery                                        ',
#  'Battery                                           ',
#  'Bomb Threat',
#  'Bomb Threat                                    ',
#  'Ch 51 Commitment',
#  'Ch 51 Commitment                               ',
#  'Check Person',
#  'Check Person                                   ',
#  'Check Property',
#  'Check Property                                 ',
#  'Child Abuse',
#  'Child Abuse                                    ',
#  'Child Neglect',
#  'Child Neglect                                  ',
#  'Civil Dispute',
#  'Confidential/Silent Case Number',
#  'Conveyance',
#  'Damaged Property',
#  'Damaged Property                               ',
#  'Death Investigation',
#  'Death Investigation                            ',
#  'Disturbance',
#  'Disturbance                                    ',
#  'Domestic/Family Trouble',
#  'Domestic/Family Trouble                        ',
#  'Drug Investigation',
#  'Drug Investigation                             ',
#  'Drug Investigation                                ',
#  'EMS Assist',
#  'EMS Assist                                     ',
#  'Emergency',
#  'Enticement/Kidnapping',
#  'Enticement/Kidnapping                          ',
#  'Escapee/Absconder',
#  'Escapee/Absconder                             ',
#  'Exposure',
#  'Exposure                                       ',
#  'Extortion',
#  'Fight (In Progress)',
#  'Fight (In Progress)                            ',
#  'Fight (In Progress)                               ',
#  'Fight In Progress',
#  'Fire Investigation',
#  'Fire Investigation                             ',
#  'Forgery',
#  'Forgery                                        ',
#  'Found Person',
#  'Found Person                                   ',
#  'Found Property',
#  'Found Property                                 ',
#  'Fraud',
#  'Fraud                                          ',
#  'Graffiti Complaint',
#  'Graffiti Complaint                            ',
#  'Gun Call',
#  'Gun Call                                       ',
#  'Information',
#  'Information                                    ',
#  'Injured Person',
#  'Injured Person                                 ',
#  'Injured Person                                    ',
#  'Intoxicated Driver',
#  'Intoxicated Driver                             ',
#  'Intoxicated Person',
#  'Intoxicated Person                             ',
#  'Intoxicated/Impaired Driver',
#  'Juvenile Complaint',
#  'Juvenile Complaint                             ',
#  'Liquor Law Violation                           ',
#  'Lost Property',
#  'Miscellaneous Sex Offense',
#  'Miscellaneous Sex Offense                      ',
#  'Miscellaneous Sex Offense                         ',
#  'Missing Adult',
#  'Missing Adult                                  ',
#  'Missing Juvenile',
#  'Missing Juvenile                               ',
#  'Murder/Homicide',
#  'Murder/Homicide                                ',
#  'Neighbor Trouble',
#  'Noise Disturbance',
#  'Noise Disturbance                              ',
#  'Non-Residential Burglary',
#  'Non-Residential Burglary                       ',
#  'Odor Complaint',
#  'Overdose',
#  'Overdose                                       ',
#  'PNB/AED Response',
#  'PNB/AED Response                               ',
#  'Person Down',
#  'Person Down                                    ',
#  'Preserve the Peace',
#  'Private Property Parking Complaint',
#  'Prostitution/Soliciting',
#  'Prostitution/Soliciting                        ',
#  'Prowler',
#  'Prowler                                        ',
#  'Residential Burglary',
#  'Residential Burglary                           ',
#  'Retail Theft',
#  'Retail Theft                                   ',
#  'Robbery',
#  'Robbery                                        ',
#  'Robbery                                           ',
#  'Safety Hazard',
#  'Safety Hazard                                  ',
#  'Serving legal Papers',
#  'Sexual Assault',
#  'Sexual Assault                                 ',
#  'Sexual Assault                                    ',
#  'Sexual Assault of a Child',
#  'Solicitor Complaint',
#  'Special Event',
#  'Special Event                                  ',
#  'Stalking Complaint',
#  'Stolen Auto',
#  'Stolen Auto                                    ',
#  'Stolen Bicycle',
#  'Stolen Other Vehicle',
#  'Strong Armed Robbery',
#  'Strong Armed Robbery                           ',
#  'Strong Armed Robbery                              ',
#  'Suspicious Person',
#  'Suspicious Person                              ',
#  'Suspicious Vehicle',
#  'Theft',
#  'Theft                                          ',
#  'Theft From Auto',
#  'Theft From Auto                               ',
#  'Theft From Auto                                   ',
#  'Threats',
#  'Threats                                        ',
#  'Towed Vehicle',
#  'Traffic Arrest',
#  'Traffic Arrest                                 ',
#  'Traffic Incident',
#  'Traffic Incident                               ',
#  'Traffic incident/Road Rage',
#  'Traffic incident/Road Rage                    ',
#  'Trespassing Complaint',
#  'Trespassing Complaint                          ',
#  'Unwanted Person',
#  'Unwanted Person                                ',
#  'Unwanted Person                                   ',
#  'Voided Case/Incident Number',
#  'Voided Case/Incident Number                    ',
#  'Weapons Violation',
#  'Weapons Violation                              ',
#  'Weapons Violation                                 ']
